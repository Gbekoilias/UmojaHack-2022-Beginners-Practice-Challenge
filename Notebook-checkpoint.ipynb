# %% [markdown]
# ## import relevant libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pylab as plb
import warnings
sns.set()

# %% [markdown]
# ## read out the relevant files

# %%
train = pd.read_csv('Train.csv')
test = pd.read_csv('Test.csv')
SampleSubmission = pd.read_csv('SampleSubmission.csv')

# %% [markdown]
# ## lets see how the files look like

# %%
train.head()
# Out:
#             ID     country  year urban_or_rural  ghsl_water_surface  \
# 0  ID_AAIethGy    Ethiopia  2016              R                 0.0
# 1  ID_AAYiaCeL    Ethiopia  2005              R                 0.0
# 2  ID_AAdurmKj  Mozambique  2009              R                 0.0
# 3  ID_AAgNHles      Malawi  2015              R                 0.0
# 4  ID_AAishfND      Guinea  2012              U                 0.0
#
#    ghsl_built_pre_1975  ghsl_built_1975_to_1990  ghsl_built_1990_to_2000  \
# 0             0.000000                 0.000000                 0.000055
# 1             0.000000                 0.000110                 0.000000
# 2             0.000000                 0.000000                 0.000000
# 3             0.000141                 0.000181                 0.000254
# 4             0.011649                 0.017560                 0.017383
#
#    ghsl_built_2000_to_2014  ghsl_not_built_up  ghsl_pop_density  \
# 0                 0.000536           0.999408         12.146134
# 1                 0.000018           0.999872        113.806716
# 2                 0.000000           1.000000          0.000000
# 3                 0.000228           0.999195          5.213320
# 4                 0.099875           0.853533         31.734661
#
#    landcover_crops_fraction  landcover_urban_fraction  \
# 0                 25.489659                  0.879484
# 1                 64.136053                  0.601427
# 2                  4.400096                  0.131900
# 3                 25.379371                  2.017136
# 4                  5.081620                 22.815984
#
#    landcover_water_permanent_10km_fraction  \
# 0                                 0.000000
# 1                                 0.000000
# 2                                 0.000000
# 3                                11.293841
# 4                                 0.005047
#
#    landcover_water_seasonal_10km_fraction  nighttime_lights  dist_to_capital  \
# 0                                0.000000          0.000000       278.788451
# 1                                0.005427          0.000000       200.986978
# 2                                0.003078          0.000000       642.594208
# 3                                0.131035          0.000000       365.349451
# 4                                0.130475          1.461894       222.867189
#
#    dist_to_shoreline    Target
# 0         769.338378  0.132783
# 1         337.135243  0.004898
# 2         169.913773  0.097320
# 3         613.591610  0.304107
# 4         192.926363  0.605328

# %%
train.shape
# Out:
# (21454, 19)

# %%
train.columns
# Out:
# Index(['ID', 'country', 'year', 'urban_or_rural', 'ghsl_water_surface',
#        'ghsl_built_pre_1975', 'ghsl_built_1975_to_1990',
#        'ghsl_built_1990_to_2000', 'ghsl_built_2000_to_2014',
#        'ghsl_not_built_up', 'ghsl_pop_density', 'landcover_crops_fraction',
#        'landcover_urban_fraction', 'landcover_water_permanent_10km_fraction',
#        'landcover_water_seasonal_10km_fraction', 'nighttime_lights',
#        'dist_to_capital', 'dist_to_shoreline', 'Target'],
#       dtype='object')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21454 entries, 0 to 21453
# Data columns (total 19 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ID                                       21454 non-null  object
#  1   country                                  21454 non-null  object
#  2   year                                     21454 non-null  int64
#  3   urban_or_rural                           21454 non-null  object
#  4   ghsl_water_surface                       21454 non-null  float64
#  5   ghsl_built_pre_1975                      21454 non-null  float64
#  6   ghsl_built_1975_to_1990                  21454 non-null  float64
#  7   ghsl_built_1990_to_2000                  21454 non-null  float64
#  8   ghsl_built_2000_to_2014                  21454 non-null  float64
#  9   ghsl_not_built_up                        21454 non-null  float64
#  10  ghsl_pop_density                         21454 non-null  float64
#  11  landcover_crops_fraction                 21454 non-null  float64
#  12  landcover_urban_fraction                 21454 non-null  float64
#  13  landcover_water_permanent_10km_fraction  21454 non-null  float64
#  14  landcover_water_seasonal_10km_fraction   21454 non-null  float64
#  15  nighttime_lights                         21454 non-null  float64
#  16  dist_to_capital                          21454 non-null  float64
#  17  dist_to_shoreline                        21454 non-null  float64
#  18  Target                                   21454 non-null  float64
# dtypes: float64(15), int64(1), object(3)
# memory usage: 3.1+ MB

# %%
train.describe()
# Out:
#                year  ghsl_water_surface  ghsl_built_pre_1975  \
# count  21454.000000        21454.000000         21454.000000
# mean    2010.060874            0.028259             0.038222
# std        4.799579            0.097490             0.113562
# min     1994.000000            0.000000             0.000000
# 25%     2008.000000            0.000000             0.000000
# 50%     2011.000000            0.000000             0.000198
# 75%     2014.000000            0.000000             0.007987
# max     2016.000000            0.969956             0.877116
#
#        ghsl_built_1975_to_1990  ghsl_built_1990_to_2000  \
# count             21454.000000             21454.000000
# mean                  0.028644                 0.012689
# std                   0.077367                 0.032745
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000043
# 50%                   0.000709                 0.001001
# 75%                   0.009868                 0.008128
# max                   0.685010                 0.515534
#
#        ghsl_built_2000_to_2014  ghsl_not_built_up  ghsl_pop_density  \
# count             21454.000000       21454.000000      21454.000000
# mean                  0.018386           0.873800         95.756775
# std                   0.040421           0.239294        209.704761
# min                   0.000000           0.000859          0.000000
# 25%                   0.000124           0.897867          3.848533
# 50%                   0.001871           0.991919         17.632672
# 75%                   0.014936           0.999532         63.225683
# max                   0.649159           1.000000       1741.256516
#
#        landcover_crops_fraction  landcover_urban_fraction  \
# count              21454.000000              21454.000000
# mean                  21.034265                 13.999061
# std                   16.751106                 23.715485
# min                    0.000000                  0.000000
# 25%                    5.610515                  0.798841
# 50%                   18.509291                  2.770159
# 75%                   33.590293                 12.621501
# max                   80.064918                 98.784092
#
#        landcover_water_permanent_10km_fraction  \
# count                             21454.000000
# mean                                  1.486849
# std                                   6.550171
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000516
# 75%                                   0.152364
# max                                  99.164018
#
#        landcover_water_seasonal_10km_fraction  nighttime_lights  \
# count                            21454.000000      21454.000000
# mean                                 0.714891          8.506543
# std                                  2.383701         21.090378
# min                                  0.000000          0.000000
# 25%                                  0.001325          0.000000
# 50%                                  0.029151          0.137333
# 75%                                  0.381969          4.830194
# max                                 56.201637        382.932769
#
#        dist_to_capital  dist_to_shoreline        Target
# count     21454.000000       21454.000000  21454.000000
# mean        289.722268         402.608539      0.350736
# std         238.811778         321.517285      0.194376
# min           0.105306           0.112080      0.000000
# 25%         115.890873         126.379463      0.195772
# 50%         256.736472         327.271973      0.293574
# 75%         401.153071         643.910675      0.499003
# max        1897.351575        1769.523906      1.000000

# %%
test.head()
# Out:
#             ID                       country  year urban_or_rural  \
# 0  ID_AAcismbB  Democratic Republic of Congo  2007              R
# 1  ID_AAeBMsji  Democratic Republic of Congo  2007              U
# 2  ID_AAjFMjzy                        Uganda  2011              U
# 3  ID_AAmMOEEC                  Burkina Faso  2010              U
# 4  ID_ABguzDxp                        Zambia  2007              R
#
#    ghsl_water_surface  ghsl_built_pre_1975  ghsl_built_1975_to_1990  \
# 0            0.000000             0.000000                 0.000000
# 1            0.000000             0.004239                 0.000238
# 2            0.007359             0.525682                 0.132795
# 3            0.000000             0.000089                 0.000036
# 4            0.000000             0.000138                 0.000623
#
#    ghsl_built_1990_to_2000  ghsl_built_2000_to_2014  ghsl_not_built_up  \
# 0                 0.000523                 0.000131           0.999347
# 1                 0.001227                 0.002860           0.991437
# 2                 0.095416                 0.042375           0.196373
# 3                 0.001519                 0.001358           0.996997
# 4                 0.000615                 0.002961           0.995663
#
#    ghsl_pop_density  landcover_crops_fraction  landcover_urban_fraction  \
# 0          0.660758                  0.990942                  0.132264
# 1          6.441547                  5.461365                  0.452400
# 2        587.516458                  2.881811                 87.387991
# 3         35.141762                 33.878927                  4.166437
# 4          3.442449                 33.491994                  3.437129
#
#    landcover_water_permanent_10km_fraction  \
# 0                                 0.069055
# 1                                 0.000000
# 2                                 3.248483
# 3                                 0.000000
# 4                                 0.133563
#
#    landcover_water_seasonal_10km_fraction  nighttime_lights  dist_to_capital  \
# 0                                0.032627          0.000000      1249.294720
# 1                                0.000000          0.000000       821.019579
# 2                                3.950374         60.070041         3.620455
# 3                                0.130727          1.333999       109.493969
# 4                                0.128997          0.502203       133.643319
#
#    dist_to_shoreline
# 0        1364.592100
# 1        1046.028681
# 2         906.057334
# 3         775.139189
# 4         835.591501

# %%
test.shape
# Out:
# (7194, 18)

# %%
test.columns
# Out:
# Index(['ID', 'country', 'year', 'urban_or_rural', 'ghsl_water_surface',
#        'ghsl_built_pre_1975', 'ghsl_built_1975_to_1990',
#        'ghsl_built_1990_to_2000', 'ghsl_built_2000_to_2014',
#        'ghsl_not_built_up', 'ghsl_pop_density', 'landcover_crops_fraction',
#        'landcover_urban_fraction', 'landcover_water_permanent_10km_fraction',
#        'landcover_water_seasonal_10km_fraction', 'nighttime_lights',
#        'dist_to_capital', 'dist_to_shoreline'],
#       dtype='object')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7194 entries, 0 to 7193
# Data columns (total 18 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ID                                       7194 non-null   object
#  1   country                                  7194 non-null   object
#  2   year                                     7194 non-null   int64
#  3   urban_or_rural                           7194 non-null   object
#  4   ghsl_water_surface                       7194 non-null   float64
#  5   ghsl_built_pre_1975                      7194 non-null   float64
#  6   ghsl_built_1975_to_1990                  7194 non-null   float64
#  7   ghsl_built_1990_to_2000                  7194 non-null   float64
#  8   ghsl_built_2000_to_2014                  7194 non-null   float64
#  9   ghsl_not_built_up                        7194 non-null   float64
#  10  ghsl_pop_density                         7194 non-null   float64
#  11  landcover_crops_fraction                 7194 non-null   float64
#  12  landcover_urban_fraction                 7194 non-null   float64
#  13  landcover_water_permanent_10km_fraction  7194 non-null   float64
#  14  landcover_water_seasonal_10km_fraction   7194 non-null   float64
#  15  nighttime_lights                         7194 non-null   float64
#  16  dist_to_capital                          7194 non-null   float64
#  17  dist_to_shoreline                        7194 non-null   float64
# dtypes: float64(14), int64(1), object(3)
# memory usage: 1011.8+ KB

# %%
test.describe()
# Out:
#               year  ghsl_water_surface  ghsl_built_pre_1975  \
# count  7194.000000         7194.000000          7194.000000
# mean   2010.899778            0.023317             0.049325
# std       3.651409            0.087915             0.132582
# min    1998.000000            0.000000             0.000000
# 25%    2010.000000            0.000000             0.000000
# 50%    2011.000000            0.000000             0.000089
# 75%    2014.000000            0.000000             0.008020
# max    2016.000000            0.991100             0.894608
#
#        ghsl_built_1975_to_1990  ghsl_built_1990_to_2000  \
# count              7194.000000              7194.000000
# mean                  0.025364                 0.016767
# std                   0.057233                 0.038079
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000019
# 50%                   0.000320                 0.000720
# 75%                   0.010774                 0.012036
# max                   0.506349                 0.275297
#
#        ghsl_built_2000_to_2014  ghsl_not_built_up  ghsl_pop_density  \
# count              7194.000000        7194.000000       7194.000000
# mean                  0.018319           0.866908         93.147365
# std                   0.039703           0.252557        211.196451
# min                   0.000000           0.008900          0.000000
# 25%                   0.000075           0.889836          1.071279
# 50%                   0.001359           0.994922         12.290615
# 75%                   0.015915           0.999738         66.695301
# max                   0.359931           1.000000       1902.876955
#
#        landcover_crops_fraction  landcover_urban_fraction  \
# count               7194.000000               7194.000000
# mean                  21.285033                 14.318006
# std                   14.916804                 24.510227
# min                    0.000000                  0.000000
# 25%                    7.855023                  0.459067
# 50%                   21.105082                  2.087011
# 75%                   31.998608                 14.174194
# max                   74.401875                 97.210607
#
#        landcover_water_permanent_10km_fraction  \
# count                              7194.000000
# mean                                  2.212083
# std                                   8.683106
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.002072
# 75%                                   0.222664
# max                                  96.978486
#
#        landcover_water_seasonal_10km_fraction  nighttime_lights  \
# count                             7194.000000       7194.000000
# mean                                 0.634295         11.508951
# std                                  2.383202         37.313751
# min                                  0.000000          0.000000
# 25%                                  0.001444          0.000000
# 50%                                  0.052594          0.000000
# 75%                                  0.351605          5.543974
# max                                 47.232629        403.455783
#
#        dist_to_capital  dist_to_shoreline
# count      7194.000000        7194.000000
# mean        332.979023         686.113119
# std         341.906808         368.546747
# min           0.437825           0.898246
# 25%         101.060708         409.104775
# 50%         241.468141         759.849023
# 75%         415.621994         954.987511
# max        1908.105037        1748.559242

# %%
SampleSubmission.head()
# Out:
#             ID  Target
# 0  ID_AAcismbB       0
# 1  ID_AAeBMsji       0
# 2  ID_AAjFMjzy       0
# 3  ID_AAmMOEEC       0
# 4  ID_ABguzDxp       0

# %%
SampleSubmission.shape
# Out:
# (7194, 2)

# %% [markdown]
# ## Lets explore our data to see some insight

# %%
train.plot(x='nighttime_lights', y='Target', kind='scatter', alpha=0.2)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='nighttime_lights', ylabel='Target'>

# %%
train.plot(x='ghsl_built_pre_1975', y='Target', kind='scatter', alpha=0.2)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='ghsl_built_pre_1975', ylabel='Target'>

# %%
train.boxplot(by='urban_or_rural', column='Target', figsize=(12, 8))
# Out:
# <AxesSubplot:title={'center':'Target'}, xlabel='urban_or_rural'>

# %%
find_data = train.groupby('country')

# %%
find_data.sum()
# Out:
#                              year  ghsl_water_surface  ghsl_built_pre_1975  \
# country
# Cameroon                  2090203           14.054691            93.032203
# Central African Republic   460704            6.218998            16.335665
# Cote d'Ivoire              965830           18.589008            78.252120
# Ethiopia                  3460873            4.574328            23.376685
# Ghana                     2849605           62.498077           140.035705
# Guinea                    1189307           40.099645            39.890911
# Kenya                     5282454           54.897212            20.865424
# Lesotho                   1597198            0.014924             1.161012
# Malawi                    3938929           56.994235            29.396658
# Mali                      2598896           20.448106            25.943077
# Mozambique                1767129           42.148877            24.168635
# Nigeria                   5416937           27.822144           147.192453
# Rwanda                    1980337           19.928468             4.231170
# Senegal                   1815265           49.412099            38.033698
# Sierra Leone              1578455           51.276067            28.072096
# Swaziland                  541685            0.566294             0.448418
# Tanzania                  4925548          125.181659            83.702731
# Togo                       664491           11.539512            25.885261
#
#                           ghsl_built_1975_to_1990  ghsl_built_1990_to_2000  \
# country
# Cameroon                                42.943986                21.658811
# Central African Republic                 1.198860                 4.234434
# Cote d'Ivoire                            6.880925                 6.943039
# Ethiopia                                37.395586                14.583705
# Ghana                                   69.268919                47.610054
# Guinea                                  20.129886                 9.319441
# Kenya                                   38.895449                17.512101
# Lesotho                                 18.208525                10.647978
# Malawi                                  15.826749                21.690368
# Mali                                    76.143663                 5.287141
# Mozambique                              59.269078                12.733430
# Nigeria                                123.995285                39.861755
# Rwanda                                  24.254552                 5.038881
# Senegal                                 29.853437                 8.363789
# Sierra Leone                            13.738520                10.144900
# Swaziland                                2.410679                 2.756737
# Tanzania                                14.897065                26.774957
# Togo                                    19.210138                 7.066286
#
#                           ghsl_built_2000_to_2014  ghsl_not_built_up  \
# country
# Cameroon                                10.784486         858.525823
# Central African Republic                 1.770423         201.241620
# Cote d'Ivoire                            9.296283         361.038626
# Ethiopia                                24.530186        1616.539509
# Ghana                                   39.877107        1059.710138
# Guinea                                  12.521281         471.038836
# Kenya                                   26.056196        2467.773619
# Lesotho                                 11.563986         752.403575
# Malawi                                  41.299859        1791.792130
# Mali                                    27.232225        1139.945788
# Mozambique                              16.892947         723.787033
# Nigeria                                 79.056554        2277.071810
# Rwanda                                  23.256633         907.290296
# Senegal                                  7.357947         769.979030
# Sierra Leone                            31.861889         649.906528
# Swaziland                                2.848406         260.969465
# Tanzania                                22.812211        2176.631377
# Togo                                     5.441220         260.857583
#
#                           ghsl_pop_density  landcover_crops_fraction  \
# country
# Cameroon                     213696.958763              11900.909980
# Central African Republic      20598.243335               1764.657993
# Cote d'Ivoire                 73698.515341               2700.939493
# Ethiopia                     188393.018523              43949.608713
# Ghana                        166839.691602              16564.112743
# Guinea                        58351.794507               3094.176327
# Kenya                        211462.533026              76847.083264
# Lesotho                       14816.326622              16667.925849
# Malawi                        70185.969136              48263.558763
# Mali                         130971.406987              28703.019622
# Mozambique                    84477.622595              14796.970103
# Nigeria                      342238.590474              61472.878998
# Rwanda                        63797.569518              27419.460116
# Senegal                      107934.754929              20460.970019
# Sierra Leone                  58249.547409               2180.571340
# Swaziland                      5215.504166               7089.134360
# Tanzania                     206003.739022              59956.982726
# Togo                          37434.067461               7436.162523
#
#                           landcover_urban_fraction  \
# country
# Cameroon                              21434.221133
# Central African Republic               3003.296631
# Cote d'Ivoire                         10960.531736
# Ethiopia                              16246.882040
# Ghana                                 32730.426993
# Guinea                                12213.550463
# Kenya                                 26878.795914
# Lesotho                                4936.327421
# Malawi                                16278.755605
# Mali                                  18197.114018
# Mozambique                            17149.562288
# Nigeria                               51968.666297
# Rwanda                                 7829.183026
# Senegal                               12607.689206
# Sierra Leone                          11642.080029
# Swaziland                              1748.118568
# Tanzania                              27267.467165
# Togo                                   7243.183749
#
#                           landcover_water_permanent_10km_fraction  \
# country
# Cameroon                                               447.754782
# Central African Republic                               336.718532
# Cote d'Ivoire                                          214.584479
# Ethiopia                                               608.034942
# Ghana                                                 1978.846070
# Guinea                                                 349.785238
# Kenya                                                 4390.472270
# Lesotho                                                 90.579238
# Malawi                                                8625.963329
# Mali                                                  1263.311040
# Mozambique                                            1236.289705
# Nigeria                                               1405.116051
# Rwanda                                                2905.402793
# Senegal                                                813.094616
# Sierra Leone                                           303.208152
# Swaziland                                               77.201266
# Tanzania                                              6779.537146
# Togo                                                    72.953883
#
#                           landcover_water_seasonal_10km_fraction  \
# country
# Cameroon                                              709.922016
# Central African Republic                              151.810511
# Cote d'Ivoire                                         227.563524
# Ethiopia                                              286.461326
# Ghana                                                1063.756615
# Guinea                                                517.763828
# Kenya                                                1021.771887
# Lesotho                                               174.375437
# Malawi                                                491.736285
# Mali                                                 3348.169125
# Mozambique                                            840.008776
# Nigeria                                              1871.056779
# Rwanda                                                167.819830
# Senegal                                              2309.393568
# Sierra Leone                                          531.758554
# Swaziland                                              31.407068
# Tanzania                                             1445.220922
# Togo                                                  147.270835
#
#                           nighttime_lights  dist_to_capital  \
# country
# Cameroon                      12696.127994     3.123918e+05
# Central African Republic        661.709287     6.072099e+04
# Cote d'Ivoire                 10797.406023     9.903400e+04
# Ethiopia                      12073.955067     5.631433e+05
# Ghana                         22769.601956     3.406199e+05
# Guinea                         2899.977937     1.553573e+05
# Kenya                         18210.416808     6.379912e+05
# Lesotho                        3224.288917     6.796448e+04
# Malawi                         7351.605570     3.962387e+05
# Mali                          13040.500947     3.862059e+05
# Mozambique                    14486.094282     7.045739e+05
# Nigeria                       33437.809597     1.001023e+06
# Rwanda                         2756.432932     5.909218e+04
# Senegal                        8412.920145     2.176386e+05
# Sierra Leone                   1810.686906     1.186947e+05
# Swaziland                      2450.885011     1.311042e+04
# Tanzania                      11926.310649     1.014273e+06
# Togo                           3492.639783     6.762851e+04
#
#                           dist_to_shoreline       Target
# country
# Cameroon                       3.256935e+05   398.107032
# Central African Republic       2.360450e+05    48.039230
# Cote d'Ivoire                  9.155030e+04   228.319761
# Ethiopia                       8.225388e+05   401.519400
# Ghana                          2.846865e+05   683.957133
# Guinea                         1.133028e+05   198.381470
# Kenya                          1.240536e+06   939.489341
# Lesotho                        2.094959e+05   287.361750
# Malawi                         9.140789e+05   529.956257
# Mali                           1.040370e+06   430.768034
# Mozambique                     1.161492e+05   290.812811
# Nigeria                        9.745788e+05  1213.606086
# Rwanda                         1.061541e+06   255.276793
# Senegal                        8.382244e+04   395.628402
# Sierra Leone                   6.169656e+04   236.375006
# Swaziland                      3.497774e+04   134.823521
# Tanzania                       9.512764e+05   713.485367
# Togo                           7.522333e+04   138.784687

# %% [markdown]
# ## Lets preprocess this data faa

# %%
# lets check out or missing variables

# %%
train.isnull().sum()
# Out:
# ID                                         0
# country                                    0
# year                                       0
# urban_or_rural                             0
# ghsl_water_surface                         0
# ghsl_built_pre_1975                        0
# ghsl_built_1975_to_1990                    0
# ghsl_built_1990_to_2000                    0
# ghsl_built_2000_to_2014                    0
# ghsl_not_built_up                          0
# ghsl_pop_density                           0
# landcover_crops_fraction                   0
# landcover_urban_fraction                   0
# landcover_water_permanent_10km_fraction    0
# landcover_water_seasonal_10km_fraction     0
# nighttime_lights                           0
# dist_to_capital                            0
# dist_to_shoreline                          0
# Target                                     0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# ID                                         0
# country                                    0
# year                                       0
# urban_or_rural                             0
# ghsl_water_surface                         0
# ghsl_built_pre_1975                        0
# ghsl_built_1975_to_1990                    0
# ghsl_built_1990_to_2000                    0
# ghsl_built_2000_to_2014                    0
# ghsl_not_built_up                          0
# ghsl_pop_density                           0
# landcover_crops_fraction                   0
# landcover_urban_fraction                   0
# landcover_water_permanent_10km_fraction    0
# landcover_water_seasonal_10km_fraction     0
# nighttime_lights                           0
# dist_to_capital                            0
# dist_to_shoreline                          0
# dtype: int64

# %%
cols_train=train.iloc[:,4:-1]

# %%
cols_train.shape
# Out:
# (21454, 14)

# %%
cols_train.head()
# Out:
#    ghsl_water_surface  ghsl_built_pre_1975  ghsl_built_1975_to_1990  \
# 0                 0.0             0.000000                 0.000000
# 1                 0.0             0.000000                 0.000110
# 2                 0.0             0.000000                 0.000000
# 3                 0.0             0.000141                 0.000181
# 4                 0.0             0.011649                 0.017560
#
#    ghsl_built_1990_to_2000  ghsl_built_2000_to_2014  ghsl_not_built_up  \
# 0                 0.000055                 0.000536           0.999408
# 1                 0.000000                 0.000018           0.999872
# 2                 0.000000                 0.000000           1.000000
# 3                 0.000254                 0.000228           0.999195
# 4                 0.017383                 0.099875           0.853533
#
#    ghsl_pop_density  landcover_crops_fraction  landcover_urban_fraction  \
# 0         12.146134                 25.489659                  0.879484
# 1        113.806716                 64.136053                  0.601427
# 2          0.000000                  4.400096                  0.131900
# 3          5.213320                 25.379371                  2.017136
# 4         31.734661                  5.081620                 22.815984
#
#    landcover_water_permanent_10km_fraction  \
# 0                                 0.000000
# 1                                 0.000000
# 2                                 0.000000
# 3                                11.293841
# 4                                 0.005047
#
#    landcover_water_seasonal_10km_fraction  nighttime_lights  dist_to_capital  \
# 0                                0.000000          0.000000       278.788451
# 1                                0.005427          0.000000       200.986978
# 2                                0.003078          0.000000       642.594208
# 3                                0.131035          0.000000       365.349451
# 4                                0.130475          1.461894       222.867189
#
#    dist_to_shoreline
# 0         769.338378
# 1         337.135243
# 2         169.913773
# 3         613.591610
# 4         192.926363

# %% [markdown]
# ## Off to create a model oo

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X=cols_train
y=train['Target']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=32)

# %%
print(X_train.shape,X_test.shape)
# Out:
# (15017, 14) (6437, 14)

# %%
LRmodel = LinearRegression()
LRmodel.fit(X_train, y_train)
LRmodel.score(X_test,y_test)
# Out:
# 0.51121703458244

# %%
from matplotlib import pyplot as plt
plt.scatter(y_test, LRmodel.predict(X_test), alpha=0.3)
